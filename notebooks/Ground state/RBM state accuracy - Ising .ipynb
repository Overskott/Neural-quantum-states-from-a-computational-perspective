# %%
# Adding src module to path
import sys
import os
module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# general imports
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib notebook

import src.utils as utils
from src.nqs import RBM, RandomHamiltonian,IsingHamiltonian, IsingHamiltonianReduced

# %%
#Initializing starting values 
visible_size = 6
hidden = 6
steps = 3000
walker_steps=100*visible_size**3
seed = 42

#Finding true ground state energy and displaying it
np.random.seed(seed)

# %%
gamma = utils.random_gamma(visible_size)
H =IsingHamiltonian(gamma=gamma)
H_r = IsingHamiltonianReduced(gamma=gamma)
#print(f"hamiltoniRn: {H}")
rbm = RBM(visible_size=visible_size, hidden_size=hidden, hamiltonian=H_r, walker_steps=walker_steps)

eig, state = np.linalg.eigh(H)

E_truth = np.min(eig)
e_truth_index = np.argmin(eig)
#print(f"Eig index: {e_truth_index}")
gstate = state[:,e_truth_index]
#print(f"g state: {gstate}")

accuracy_list = []
state_acc_list = []
steps_list=[]

for i in range(1,steps):
    energy = rbm.train(iterations=1, lr=0.01, print_energy=False , termination_condition=(0.01, E_truth))
    
    
    #print(f"Ground state energy found: {energy_list[-1]}")
    #print(f"True energy ground state: {E_truth}")
    accuracy = utils.relative_error(E_truth, energy)
    print(f"current error: {accuracy})
    #print(f"Accuracy: {accuracy}") # relative error
    
    state_error = 1- (np.abs(gstate.T.conj() @ rbm.wave_function()))
    #print(f"RBM state error: {state_error}")
    
    accuracy_list.append(accuracy)
    state_acc_list.append(state_error)
# Out:
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.266718864440918 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2456111907958984 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2255802154541016 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2142200469970703 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2052576541900635 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2190473079681396 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2099361419677734 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.252779483795166 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2687041759490967 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.276792526245117 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.3086659908294678 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2576029300689697 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2851531505584717 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2911572456359863 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.272646903991699 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.284599542617798 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2748799324035645 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.254051446914673 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2620952129364014 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2706990242004395 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.250494956970215 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2959659099578857 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2522947788238525 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2822346687316895 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2614328861236572 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.285914897918701 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2671334743499756 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.4174625873565674 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.292853355407715 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2776246070861816 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2920665740966797 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.262932538986206 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.266298532485962 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2613041400909424 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.262817144393921 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.271740436553955 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.282728910446167 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2688286304473877 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.283737897872925 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2521934509277344 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2655038833618164 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2716469764709473 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.25974178314209 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2752795219421387 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.276453733444214 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2759528160095215 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2622883319854736 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.28225040435791 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.3132474422454834 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.279825210571289 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.277631998062134 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2934043407440186 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2593166828155518 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.278172254562378 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.295822858810425 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.266930103302002 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2708470821380615 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2739744186401367 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2625675201416016 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.265815019607544 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.266678810119629 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.277902841567993 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.273283004760742 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.269148588180542 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2514758110046387 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2671186923980713 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.270197629928589 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.26977801322937 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2856924533843994 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.282510995864868 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.263070821762085 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.284010410308838 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2915523052215576 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2365965843200684 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2544779777526855 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.309093475341797 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2664170265197754 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.3007922172546387 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2722508907318115 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.285839796066284 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.270432710647583 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2634360790252686 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2815563678741455 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2806339263916016 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.280482292175293 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.289250135421753 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.264498472213745 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.282583475112915 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2893850803375244 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.266075611114502 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.279247999191284 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2788779735565186 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2707877159118652 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.278510808944702 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2838211059570312 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2852401733398438 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.276651382446289 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2954649925231934 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.288304567337036 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.287849187850952 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.284111738204956 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2785661220550537 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2765748500823975 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2928824424743652 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.288625478744507 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2922279834747314 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2887463569641113 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.283827781677246 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2727959156036377 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.300696849822998 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.272663116455078 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2908647060394287 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2868411540985107 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.2736127376556396 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.275416612625122 sec
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x000001A729D4BA00>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -3.039850223414474)}] took: 2.