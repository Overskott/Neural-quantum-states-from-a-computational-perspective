# %%
# Adding src module to path
import sys
import os
module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# general imports
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib notebook

import src.utils as utils
from src.nqs import RBM, RandomHamiltonian,IsingHamiltonian, IsingHamiltonianReduced

# %%
#Initializing starting values 
visible_size = 6
hidden = 18
steps = 3000
walker_steps=100*visible_size**3
seed = 45

#Finding true ground state energy and displaying it
np.random.seed(seed)

H = RandomHamiltonian(n = visible_size)
#print(f"hamiltonian: {H}")
rbm = RBM(visible_size=visible_size, hidden_size=hidden, hamiltonian=H, walker_steps=walker_steps)

eig, state = np.linalg.eigh(H)

E_truth = np.min(eig)
e_truth_index = np.argmin(eig)
#print(f"Eig index: {e_truth_index}")
gstate = state[:,e_truth_index]
#print(f"g state: {gstate}")

# %%
accuracy_list = []
state_acc_list = []
steps_list=[]

for i in range(1,steps):
    energy = rbm.train(iterations=1, lr=0.01, print_energy=False, termination_condition=(0.01, E_truth))
    #print(rbm.train.run_time)
    
    #print(f"Ground state energy found: {energy_list[-1]}")
    #print(f"True energy ground state: {E_truth}")
    accuracy = utils.relative_error(E_truth, energy)
    #print(f"Accuracy: {accuracy}") # relative error
    print(f"current error: {accuracy}")
    state_error = 1- (np.abs(gstate.T.conj() @ rbm.wave_function()))
    #print(f"RBM state error: {state_error}")
    
    accuracy_list.append(accuracy)
    state_acc_list.append(state_error)
# Out:
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4386680126190186 sec
# current error: [0.96330406]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3664498329162598 sec
# current error: [0.95121835]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3782901763916016 sec
# current error: [0.93720238]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.376958131790161 sec
# current error: [0.9179821]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.382539749145508 sec
# current error: [0.90589909]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3846797943115234 sec
# current error: [0.90373017]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4810283184051514 sec
# current error: [0.88915664]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4766345024108887 sec
# current error: [0.86990549]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.456707000732422 sec
# current error: [0.8646043]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.445474624633789 sec
# current error: [0.84406498]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4141225814819336 sec
# current error: [0.83335013]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.468125581741333 sec
# current error: [0.83046195]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.442624807357788 sec
# current error: [0.82322488]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.437055826187134 sec
# current error: [0.81149687]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4088995456695557 sec
# current error: [0.80041931]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4396331310272217 sec
# current error: [0.79465954]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4538733959198 sec
# current error: [0.77600896]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.423051357269287 sec
# current error: [0.76865356]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4468934535980225 sec
# current error: [0.75782962]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4650564193725586 sec
# current error: [0.7490937]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.481019973754883 sec
# current error: [0.74533015]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4232988357543945 sec
# current error: [0.73275829]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.406036138534546 sec
# current error: [0.72494391]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.432765245437622 sec
# current error: [0.71971892]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4643826484680176 sec
# current error: [0.72421642]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.427495241165161 sec
# current error: [0.7175848]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4103760719299316 sec
# current error: [0.71169209]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.454723596572876 sec
# current error: [0.69125021]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.504960298538208 sec
# current error: [0.69913318]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.490755796432495 sec
# current error: [0.69139817]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.414295196533203 sec
# current error: [0.69117164]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.490309715270996 sec
# current error: [0.69376703]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.403855800628662 sec
# current error: [0.68821674]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4290969371795654 sec
# current error: [0.68133126]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4202730655670166 sec
# current error: [0.68041171]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4236011505126953 sec
# current error: [0.67709385]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4582953453063965 sec
# current error: [0.68058657]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.5000555515289307 sec
# current error: [0.66941478]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.491131067276001 sec
# current error: [0.67033494]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.46728777885437 sec
# current error: [0.66724837]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.475222110748291 sec
# current error: [0.66659257]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.46775221824646 sec
# current error: [0.66409675]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4340198040008545 sec
# current error: [0.65559438]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.397709846496582 sec
# current error: [0.6564473]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.449378252029419 sec
# current error: [0.65398184]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4438395500183105 sec
# current error: [0.64995663]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4227535724639893 sec
# current error: [0.64921678]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4206504821777344 sec
# current error: [0.64499888]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4664201736450195 sec
# current error: [0.63758182]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.460892915725708 sec
# current error: [0.64060801]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4427754878997803 sec
# current error: [0.63758481]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.434359073638916 sec
# current error: [0.63577549]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.422895669937134 sec
# current error: [0.63825067]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.49422287940979 sec
# current error: [0.63388851]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4316000938415527 sec
# current error: [0.63454207]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.408097743988037 sec
# current error: [0.63230636]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.409578561782837 sec
# current error: [0.63364721]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4644482135772705 sec
# current error: [0.62723119]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4528534412384033 sec
# current error: [0.63147189]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4100728034973145 sec
# current error: [0.63061682]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4560887813568115 sec
# current error: [0.62546657]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.440434455871582 sec
# current error: [0.62697428]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4654946327209473 sec
# current error: [0.62796871]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4201676845550537 sec
# current error: [0.62741694]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.404628276824951 sec
# current error: [0.62834385]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4774246215820312 sec
# current error: [0.62489302]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.466268301010132 sec
# current error: [0.62033036]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4080255031585693 sec
# current error: [0.61642497]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4232940673828125 sec
# current error: [0.62393669]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4532840251922607 sec
# current error: [0.62091118]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.445953130722046 sec
# current error: [0.61625246]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.410064458847046 sec
# current error: [0.60617002]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4299230575561523 sec
# current error: [0.61866343]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.439304828643799 sec
# current error: [0.60897724]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.442152500152588 sec
# current error: [0.61328418]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4116384983062744 sec
# current error: [0.60680798]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4156477451324463 sec
# current error: [0.60504182]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4015426635742188 sec
# current error: [0.60363234]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4693875312805176 sec
# current error: [0.5990263]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4496734142303467 sec
# current error: [0.60213968]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.423015832901001 sec
# current error: [0.59514519]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.41622257232666 sec
# current error: [0.58650811]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4117259979248047 sec
# current error: [0.58202848]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.45953369140625 sec
# current error: [0.57196115]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4151668548583984 sec
# current error: [0.55975131]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4027676582336426 sec
# current error: [0.55614995]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4472029209136963 sec
# current error: [0.55630852]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.442291736602783 sec
# current error: [0.56705457]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.432373523712158 sec
# current error: [0.56158014]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.435393810272217 sec
# current error: [0.55643123]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4416329860687256 sec
# current error: [0.5563118]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.435105323791504 sec
# current error: [0.54336469]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.422814130783081 sec
# current error: [0.54580759]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.418463945388794 sec
# current error: [0.55101554]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.498903274536133 sec
# current error: [0.55188474]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4837467670440674 sec
# current error: [0.54135194]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3923094272613525 sec
# current error: [0.52707203]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4123754501342773 sec
# current error: [0.54232849]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.403536558151245 sec
# current error: [0.53801216]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.382199764251709 sec
# current error: [0.53892715]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4169180393218994 sec
# current error: [0.53509945]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4264707565307617 sec
# current error: [0.53408505]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3964626789093018 sec
# current error: [0.53122012]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.391807794570923 sec
# current error: [0.53007752]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3761942386627197 sec
# current error: [0.52545157]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.386711597442627 sec
# current error: [0.52196029]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.395820379257202 sec
# current error: [0.51247662]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.366485595703125 sec
# current error: [0.50869171]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.455110788345337 sec
# current error: [0.5175483]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4641427993774414 sec
# current error: [0.51121776]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4620792865753174 sec
# current error: [0.50272068]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4195942878723145 sec
# current error: [0.50466248]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.424509048461914 sec
# current error: [0.4941652]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.413062334060669 sec
# current error: [0.49115828]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4499127864837646 sec
# current error: [0.48293812]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4282519817352295 sec
# current error: [0.47926795]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.406282663345337 sec
# current error: [0.47679485]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.40480899810791 sec
# current error: [0.47782293]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4598143100738525 sec
# current error: [0.47036056]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4904263019561768 sec
# current error: [0.47373083]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4366872310638428 sec
# current error: [0.47413636]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4319965839385986 sec
# current error: [0.45742766]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.468690872192383 sec
# current error: [0.46072499]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4909563064575195 sec
# current error: [0.45868531]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.483746290206909 sec
# current error: [0.45956103]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4363622665405273 sec
# current error: [0.45198085]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.409747838973999 sec
# current error: [0.44460871]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.400991439819336 sec
# current error: [0.44384335]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4234912395477295 sec
# current error: [0.44247281]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4316885471343994 sec
# current error: [0.4381059]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4628193378448486 sec
# current error: [0.43291372]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4567737579345703 sec
# current error: [0.43295782]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4995570182800293 sec
# current error: [0.42997169]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.507948637008667 sec
# current error: [0.41994637]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.451420545578003 sec
# current error: [0.41762919]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.435990333557129 sec
# current error: [0.4163731]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4125142097473145 sec
# current error: [0.41153471]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4014976024627686 sec
# current error: [0.40517464]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.422114849090576 sec
# current error: [0.39904546]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.414857864379883 sec
# current error: [0.39873223]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4267354011535645 sec
# current error: [0.38951469]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.43465518951416 sec
# current error: [0.3825407]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4524426460266113 sec
# current error: [0.38820549]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.43538236618042 sec
# current error: [0.38541983]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4188129901885986 sec
# current error: [0.38507928]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.432793378829956 sec
# current error: [0.3769335]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4289557933807373 sec
# current error: [0.37262641]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.424767017364502 sec
# current error: [0.36451365]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.427159547805786 sec
# current error: [0.3562841]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.444798231124878 sec
# current error: [0.3579504]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.446276903152466 sec
# current error: [0.35182466]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4462294578552246 sec
# current error: [0.34619912]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4346253871917725 sec
# current error: [0.34457258]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4209439754486084 sec
# current error: [0.33689758]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4547085762023926 sec
# current error: [0.33375649]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4661242961883545 sec
# current error: [0.32901109]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4266693592071533 sec
# current error: [0.32454615]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.407438278198242 sec
# current error: [0.31789075]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4108660221099854 sec
# current error: [0.31209232]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.408832311630249 sec
# current error: [0.31091168]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4092295169830322 sec
# current error: [0.30221985]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.508446455001831 sec
# current error: [0.29999416]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4830501079559326 sec
# current error: [0.29869195]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.471153974533081 sec
# current error: [0.29292108]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4776082038879395 sec
# current error: [0.28823772]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4753386974334717 sec
# current error: [0.2841633]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4412477016448975 sec
# current error: [0.27882917]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4188990592956543 sec
# current error: [0.27303024]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4697201251983643 sec
# current error: [0.27187236]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4662563800811768 sec
# current error: [0.26301642]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.455503225326538 sec
# current error: [0.26232775]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4357683658599854 sec
# current error: [0.26082113]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4716291427612305 sec
# current error: [0.2545855]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.466987371444702 sec
# current error: [0.24754315]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4426655769348145 sec
# current error: [0.24797589]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4212379455566406 sec
# current error: [0.24891108]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.456725597381592 sec
# current error: [0.24488332]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.476714849472046 sec
# current error: [0.2437677]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4374003410339355 sec
# current error: [0.24026894]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.441018581390381 sec
# current error: [0.24318427]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.432663679122925 sec
# current error: [0.23971427]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4541919231414795 sec
# current error: [0.23686851]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.455263137817383 sec
# current error: [0.23319461]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.457789659500122 sec
# current error: [0.23745474]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4578664302825928 sec
# current error: [0.2327072]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4777207374572754 sec
# current error: [0.22716222]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4842417240142822 sec
# current error: [0.22762223]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4259331226348877 sec
# current error: [0.22543885]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4223530292510986 sec
# current error: [0.22236825]
# Warming up the walker...
# ...
# current error: [0.00024094]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.372119426727295 sec
# current error: [0.00017847]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.341883420944214 sec
# current error: [3.87319961e-06]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.36199951171875 sec
# current error: [0.00011792]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3453705310821533 sec
# current error: [0.0001555]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.337472677230835 sec
# current error: [0.00023278]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.340174913406372 sec
# current error: [0.00032001]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.363469123840332 sec
# current error: [0.00022713]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3454480171203613 sec
# current error: [0.00024312]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3620641231536865 sec
# current error: [0.00023489]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.377225637435913 sec
# current error: [0.00067406]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3609507083892822 sec
# current error: [0.00027365]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.365889310836792 sec
# current error: [0.00038728]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3556411266326904 sec
# current error: [0.00087016]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3879644870758057 sec
# current error: [0.00091925]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3641889095306396 sec
# current error: [0.00050501]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4019954204559326 sec
# current error: [0.00015342]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.36252760887146 sec
# current error: [0.00017637]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.348806858062744 sec
# current error: [0.00045388]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.366415023803711 sec
# current error: [2.28368033e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.378674030303955 sec
# current error: [0.00086892]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4108574390411377 sec
# current error: [0.00111603]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.447932720184326 sec
# current error: [0.00055485]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.43727707862854 sec
# current error: [0.000244]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4387948513031006 sec
# current error: [7.39729004e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.408473253250122 sec
# current error: [0.00018997]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.371760845184326 sec
# current error: [9.16766047e-06]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3633792400360107 sec
# current error: [9.1289075e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.35282564163208 sec
# current error: [1.76516013e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.36934757232666 sec
# current error: [9.2630173e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.35360050201416 sec
# current error: [0.00019687]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4062812328338623 sec
# current error: [0.0004085]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.384173631668091 sec
# current error: [0.00013484]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.383545398712158 sec
# current error: [4.63864364e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4071531295776367 sec
# current error: [0.00022933]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.403749942779541 sec
# current error: [0.00030188]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3757224082946777 sec
# current error: [5.08631209e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.386723518371582 sec
# current error: [0.00034296]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3755154609680176 sec
# current error: [5.6027524e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3702163696289062 sec
# current error: [0.00015405]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3873836994171143 sec
# current error: [0.00037257]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3764843940734863 sec
# current error: [0.00010211]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3673593997955322 sec
# current error: [0.00014487]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3909220695495605 sec
# current error: [0.00019096]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3529608249664307 sec
# current error: [0.00020192]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.35538649559021 sec
# current error: [0.00013014]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.366671562194824 sec
# current error: [0.00010529]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3761627674102783 sec
# current error: [6.57780993e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.369997501373291 sec
# current error: [0.00010129]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3707516193389893 sec
# current error: [3.95994937e-06]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.393190622329712 sec
# current error: [1.21607379e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3884963989257812 sec
# current error: [0.00021892]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3712143898010254 sec
# current error: [0.00021259]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3707101345062256 sec
# current error: [0.0001775]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.373699188232422 sec
# current error: [6.14781608e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.387964963912964 sec
# current error: [3.54831728e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4219512939453125 sec
# current error: [3.27581479e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.373502492904663 sec
# current error: [1.82705953e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3828203678131104 sec
# current error: [6.82169568e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3585658073425293 sec
# current error: [0.00011188]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3672022819519043 sec
# current error: [4.30209514e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.4118564128875732 sec
# current error: [2.07630907e-05]
# Warming up the walker...
# func:train args:[(<src.nqs.RBM object at 0x0000024C9D93A4C0>,), {'iterations': 1, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.312108954668243)}] took: 2.3776659965515137 sec
# current error: [0.0001226]

# %%
plt.figure(0)
plt.semilogx(accuracy_list)
plt.semilogx(state_acc_list)
plt.legend([r'$\epsilon_{rel}$', r"$\epsilon_{fid}$"])
plt.ylabel("Error")
plt.xlabel("Training steps")
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Save figure as pdf
username = os.getlogin()
desktop_path = f"{os.path.expanduser(os.getenv('USERPROFILE'))}\\Desktop"

path = f"{desktop_path}/RBM state accuracy-Random.pdf"

plt.savefig(f"{path}",bbox_inches = "tight")
