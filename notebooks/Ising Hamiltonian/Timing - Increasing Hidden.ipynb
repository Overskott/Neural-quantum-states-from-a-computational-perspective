# %%
# From here: https://stackoverflow.com/questions/49264194/import-py-file-in-another-directory-in-jupyter-notebook
import sys
import os
from datetime import datetime

module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import numpy as np
import copy

import src.utils as utils
from src.nqs import RBM, IsingHamiltonian, IsingHamiltonianReduced
from config_parser import get_config_file

import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
visible_size = 4
hidden_size = 6
seed = 44  # Seed for random number generator
walker_steps = 1000
gradient_steps = 100

# %%
np.random.seed(seed)

gamma = utils.random_gamma(visible_size)
ih = IsingHamiltonian(gamma=gamma)
ihr = IsingHamiltonianReduced(gamma=gamma)

# %%
eig,_ = np.linalg.eigh(ih)
I_truth = np.min(eig)
print(f"E_truth: {I_truth}")
# Out:
# E_truth: -3.313112070611122

# %%
time_matrix = []
time_reduced = []
n_list = []


seed = 44  # Seed for random number generator
walker_steps = 100
gradient_steps = 100



visible_size = 6
for i in range(2, 20):
    
    
    hidden_size = visible_size*i
    n_list.append(visible_size*hidden_size)
    
    gamma = utils.random_gamma(visible_size)
    ih = IsingHamiltonian(gamma=gamma)
    ihr = IsingHamiltonianReduced(gamma=gamma)
    
    ising_rbm = RBM(visible_size=visible_size, hidden_size=hidden_size, hamiltonian=ih, walker_steps=walker_steps)
    ising_rbm.train(iterations=gradient_steps, lr=0.01,print_energy=False)
    time_matrix.append(ising_rbm.train.run_time)

    ising_reduced_rbm = RBM(visible_size=visible_size, hidden_size=hidden_size, hamiltonian=ihr, walker_steps=walker_steps)
    ising_reduced_rbm.train(iterations=gradient_steps, lr=0.01,print_energy=False)
    time_reduced.append(ising_reduced_rbm.train.run_time)
# Out:
# func:train args:[(<src.nqs.RBM object at 0x0000014683465EB0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.7713820934295654 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682BAEF10>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.463484525680542 sec
# func:train args:[(<src.nqs.RBM object at 0x00000146FF332F40>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.7361528873443604 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014683465EB0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.3547017574310303 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682BAEF10>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.7945985794067383 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014680F30910>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.5844249725341797 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014683465EE0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.9862136840820312 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682B4EC40>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.647592782974243 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014680F30910>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.978816509246826 sec
# func:train args:[(<src.nqs.RBM object at 0x00000146FF169D90>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.7110509872436523 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014683465CD0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.1569130420684814 sec
# func:train args:[(<src.nqs.RBM object at 0x00000146FF332F40>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.927217483520508 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682B5DEB0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.1477012634277344 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014680F30EE0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 2.9525740146636963 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014683465C70>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.180737257003784 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682BAEF70>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.018690824508667 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014680F30EE0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.3073925971984863 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682B4EC40>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.244319438934326 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014683465CD0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.5377166271209717 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682BAEF10>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.46445369720459 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682B3D460>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.579362630844116 sec
# func:train args:[(<src.nqs.RBM object at 0x00000146FF332F40>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.5094587802886963 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014683465CD0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.756079912185669 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014680F30910>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.7237207889556885 sec
# func:train args:[(<src.nqs.RBM object at 0x00000146FF332F40>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.7615466117858887 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682BAEF70>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.8097946643829346 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014683465CD0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.9035398960113525 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682B5DEB0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.919337511062622 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682BAEF70>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.8265295028686523 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014680F30EE0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 4.016902923583984 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014683465CD0>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 4.123265027999878 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682BAEF10>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 4.313531398773193 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682B4EC40>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.9834959506988525 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014682B3D460>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 4.202051877975464 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014683465C10>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 3.9551470279693604 sec
# func:train args:[(<src.nqs.RBM object at 0x0000014680F30910>,), {'iterations': 100, 'lr': 0.01, 'print_energy': False}] took: 4.441303491592407 sec

# %%
plt.figure(2)

plt.plot(n_list, time_matrix, marker = 'o')
plt.plot(n_list, time_reduced, marker = 'o')
plt.grid()

#plt.title("Training time using matrix and reduced Hamiltonian representations")
plt.legend(['Matrix', 'Reduced'], title=" Ising Hamiltonian")
plt.xlabel('Number of parameters')
plt.ylabel('Time (s)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Time (s)')

# %%
# Save figure as pdf
username = os.getlogin()
desktop_path = f"{os.path.expanduser(os.getenv('USERPROFILE'))}\\Desktop"

date_format = '%Y.%m.%d:%H%M'

path = f"{desktop_path}/Timing - Increasing Hidden.pdf"

plt.savefig(f"{path}",bbox_inches = "tight")
