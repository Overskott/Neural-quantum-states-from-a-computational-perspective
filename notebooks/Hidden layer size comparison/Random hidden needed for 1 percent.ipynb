# %%
# Adding src module to path
import sys
import os
module_path = os.path.abspath(os.path.join('../..'))

print(f"module path {module_path}")
if module_path not in sys.path:
    sys.path.append(module_path)
# Out:
# module path C:\Users\overs\Python\Master-Thesis-Project

# %%
# general imports
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib notebook

import src.utils as utils
from src.nqs import RBM,  RandomHamiltonian

# %% [markdown]
# ## Testing hidden node accuracy
#
# Training several RBMs with increasing number of visible nodes. For each RBM we test how increasing the number of hidden nodes affects accuracy.

# %%
seed=42
#Initializing starting values

# %%
visible_list = []
hidden_list = []
for v in range(2,10):
    np.random.seed(seed)
    visible_size = v

    hamiltonian = RandomHamiltonian(n=v)
    eig,_ = np.linalg.eigh(hamiltonian)
    E_truth = np.min(eig)
    
    for h in range(1, 50):
        
        rbm = RBM(visible_size=visible_size, hidden_size=h, hamiltonian=hamiltonian, walker_steps=1000)
        
        energies = rbm.train(iterations=2000, lr=0.01, print_energy=False, termination_condition=(0.01, E_truth))

        if utils.relative_error(energies[-1], E_truth) < 0.01:
            visible_list.append(v)
            hidden_list.append(h)
            break
# Out:
# func:train args:[(<src.nqs.RBM object at 0x0000013B858CF8B0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -4.801074844265203)}] took: 51.087048292160034 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E85E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -7.963680879511855)}] took: 129.13731360435486 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F3790>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -13.055371981671408)}] took: 560.6596322059631 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B80B24040>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -13.055371981671408)}] took: 397.8436019420624 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F3790>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -21.12676076644112)}] took: 585.2124960422516 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -21.12676076644112)}] took: 779.6827330589294 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F32B0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -21.12676076644112)}] took: 786.7123820781708 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B80B24040>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -21.12676076644112)}] took: 643.4691252708435 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B8340BA60>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.111023244552154)}] took: 611.6391756534576 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833FA1F0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.111023244552154)}] took: 823.5744869709015 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.111023244552154)}] took: 830.2954776287079 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83248F10>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.111023244552154)}] took: 855.2898812294006 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E85E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.111023244552154)}] took: 882.1277599334717 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E88E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.111023244552154)}] took: 913.2278480529785 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B80B24040>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.111023244552154)}] took: 941.0455594062805 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B8340BA60>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.111023244552154)}] took: 966.9231402873993 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833FA1F0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.111023244552154)}] took: 1001.3545682430267 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.111023244552154)}] took: 1027.271518945694 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83248F10>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -30.111023244552154)}] took: 801.5600781440735 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 683.1711437702179 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E88E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 918.1338613033295 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833FA1F0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 969.2424869537354 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B80B24040>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1019.7112746238708 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F32B0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1078.9348080158234 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F3790>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1138.5884764194489 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83248F10>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1183.8866076469421 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1236.9642806053162 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E88E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1310.68896484375 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833FA1F0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1358.177264213562 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B80B24040>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1412.9015550613403 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F32B0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1463.8006553649902 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F3790>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1520.7368128299713 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83248F10>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1574.85640335083 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1622.2308149337769 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E88E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1678.9288079738617 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833FA1F0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1724.9112272262573 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B80B24040>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1759.0739998817444 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F32B0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1798.1863198280334 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F3790>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1838.7401366233826 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83248F10>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1896.6787350177765 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1955.4666984081268 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E88E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 1999.6179876327515 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833FA1F0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 2029.6000957489014 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B80B24040>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 2101.321704149246 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F32B0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 2152.516741991043 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F3790>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 2204.5177409648895 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83248F10>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 2256.937955379486 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 2303.3106060028076 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E88E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 2340.1641085147858 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833FA1F0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 2405.4541075229645 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B80B24040>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 2434.6255571842194 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F32B0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 2543.076064825058 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F3790>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -43.16179836016568)}] took: 2506.9569220542908 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F32B0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 790.9759676456451 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 1140.651549577713 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B80B24040>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 1229.903156042099 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B8340BA60>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 1352.0323884487152 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E85E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 1473.3977119922638 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E88E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 1545.0144650936127 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F3790>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 1652.0497813224792 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F32B0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 1745.7837007045746 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 1853.4080047607422 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B80B24040>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 1933.204827785492 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B8340BA60>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 2077.1528759002686 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E85E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 2142.953113794327 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E88E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 2247.6811995506287 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F3790>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 2348.6222021579742 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F32B0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 2423.9924492836 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 2530.9733471870422 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B80B24040>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 2633.3972375392914 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B8340BA60>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 2720.388961791992 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E85E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 2824.9968798160553 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833E88E0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 2911.350102186203 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F3790>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 3016.163263320923 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B833F32B0>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 3110.1524562835693 sec
# func:train args:[(<src.nqs.RBM object at 0x0000013B83405D90>,), {'iterations': 2000, 'lr': 0.01, 'print_energy': False, 'termination_condition': (0.01, -62.827663160896954)}] took: 3202.7618548870087 sec

# %%
#labels = [f"Hidden size= {i}" for i in range(1,5)]

print(f"visble= {visible_list}")
print(f"hidden = {hidden_list}")
import math

yint = range(math.floor(min(visible_list)), math.ceil(max(visible_list))+1)

plt.figure(0)
plt.yticks(yint)
plt.plot(yint, hidden_list, marker='o')
    


plt.xlabel("Hidden nodes required")
plt.ylabel(r'Visible nodes')
plt.grid()
#plt.legend(labels)
# Out:
# visble= [2, 3, 4, 5]
# hidden = [1, 1, 2, 4]
# <img src="data:image/png;base64,..." width="640">

# %%
labels.append("True energy")
plt.figure(i)
# plt.ioff() # uncomment to stop plotting in notebook

yint = range(min(visible_list), math.ceil(visible_list))+1)
matplotlib.pyplot.yticks(yint)

for energy in energy_list:
    plt.plot(energy)
    plt.xlabel('Gradient steps')
    plt.ylabel('Energy')

plt.title(f"Training of RBM with {visible_size} visible nodes")
plt.axhline(y=E_truth, color='k', linestyle='--')
plt.legend(labels)

# %%
# Save figure as pdf
username = os.getlogin()
desktop_path = f"{os.path.expanduser(os.getenv('USERPROFILE'))}\\Desktop"

date_format = '%Y.%m.%d;%H%M'

path = f"{desktop_path}\\{datetime.now().strftime(date_format)}-2_node_plots"
os.makedirs(path)
plt.savefig(f"{path}/{n_vis}nodes.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       7 path = f"{desktop_path}\\{datetime.now().strftime(date_format)}-2_node_plots"
#       8 os.makedirs(path)
# ----> 9 plt.savefig(f"{path}/{n_vis}nodes.pdf")
#
# NameError: name 'n_vis' is not defined
